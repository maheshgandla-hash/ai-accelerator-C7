# %% [markdown]
# <a href="https://colab.research.google.com/github/eng-accelerator/ai-accelerator-C7/blob/main/Day%204/HF_inference_endpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Get your hf token first
# - go to https://huggingface.co/settings/tokens
# - generate a token, copy it
# - paste below and the code should work
# - https://huggingface.co/docs/inference-providers/pricing

# %%
import os
from openai import OpenAI

client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key="hf_token",
)

completion = client.chat.completions.create(
    model="meta-llama/Llama-3.1-8B-Instruct:novita",
    messages=[
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
)

print(completion.choices[0].message.content)
# Out:
# The capital of France is Paris.
